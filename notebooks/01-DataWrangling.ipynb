# %%
import pandas as pd
import urllib
import requests
from pathlib import Path
import numpy as np
import os
import json
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Data Wrangling
#
# 1. Unify the file formats (i.e., `json` --> `csv`)
# 1. Merge metadata from multiple sources (i.e., NIH Common Fund repositories and Database Commons)
# 1. Add URLs of resources if missing (i.e., Journal homepages using `Sourceid`)
# 1. Add our own IDs for individual resources by updating (`global_data-portal_id_map.csv`)
# 1. Add resource connection status
#
# **To-Do**
# - [ ] Merge NIH data portals

# %%
EVALUATION_DATE_FOLDER = 'Nov-21-2023'

# %% [markdown]
# ## Data Portals

# %%
"""
Load the original data
"""
df = pd.read_json(os.path.join('../input', EVALUATION_DATE_FOLDER, 'database-commons.json'))

# df = df.head(10) # for testing purposes

# %%
"""
We use underscore lowercase column names
"""
df.columns = (df.columns.str.replace('(?<=[a-z])(?=[A-Z])', '_', regex=True).str.lower())

# %%
"""
Drop columns that we don't need
"""
df.drop(columns=['biodb_ranks', 'rating_list'], inplace=True)

# %%
"""
The id from the sources are consistently "source_id"
The values should be a string type, and it has the prefix that represents the source (e.g. dc_ for Database Commons)
"""
df.rename(columns={ "db_id": "source_id" }, inplace=True)
df.source_id = df.source_id.apply(lambda x: 'dc_' + str(x))

# %%
"""
Some columns from data commons are in json format, we need to convert them to string
Example: [{ "id": 1, "name": "foo" }, { "id": 2, "name": "bar" }] --> 'foo, bar'
"""
json_column_names_and_keys = {
    'data_type_list': 'datatypeName', 
    'category_list': 'name',
    'keywords_list': 'name',
    'data_object_list': 'name',
    'organism_list': 'organismName',
    'theme_list': 'name'
}

for (column, key) in json_column_names_and_keys.items():
    df[column] = df[column].apply(lambda x: ', '.join([object[key] for object in x]))

# %%
# This takes too much time. We will instead just run WAVE API requests for all URLs.
# # Check the connection status and put that as a `reachable` column

# # TODO: a faster way to do this?
# def check_connection_status(url):
#     print(url)
#     try:
#         status = requests.get(url)
#     except Exception:
#         return False
#     return status.status_code == 200
    
# df['reachable'] = df['url'].apply(lambda x: check_connection_status(x))

# %% [markdown]
# ### Update the ID Mapping Table (`data-portal_id_map.csv`)

# %%
"""
create or update a mapping table (i.e., `data-portal_id_map.csv`)
"""
# Load the data first
file = Path(os.path.join('../output', 'data-portal_id_map.csv'))
if file.exists():
    df_map = pd.read_csv(file)
else:
    df_map = pd.DataFrame(columns=['id', 'source_id', 'date_added'])

# Find rows that does not already exist in the table
df_temp = df_map.merge(df, how='outer', on='source_id', indicator=True)
df_new_resources = df_temp[df_temp['_merge'] == 'right_only'][['source_id']]

# Ensure to assign new `id`s, i.e., New `id` == max id + 1
max_id = df_map.id.max()
max_id = 0 if max_id is np.nan else max_id
new_id = max_id + 1

df_new_resources.insert(0, 'id', range(new_id, new_id + len(df_new_resources)))
df_new_resources['date_added'] = pd.to_datetime('today').strftime('%m-%d-%Y')

pd.concat([df_map, df_new_resources], axis=0).to_csv(file, index=False)

# %% [markdown]
# ### Save the Metadata of Data Portals (`data-portal_metadata.csv`)

# %%
"""
Add the `id` column to the original metadata
"""
df_map = pd.read_csv(file)
df_meta = df_map[['id', 'source_id']].merge(df, how='right', on='source_id')
df_meta.to_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'data-portal_metadata.csv'), index=False)
df_meta.head(1)
# Out:
#    id source_id short_name  accession  \
# 0   1   dc_3061      DAVID  DBC003061
#
#                                            full_name  \
# 0  Database for Annotation, Visualization and Int...
#
#                                          description  \
# 0  The Database for Annotation, Visualization and...
#
#                          url  founded_year           host_institution  \
# 0  https://david.ncifcrf.gov          2003  National Cancer Institute
#
#                                              address  ...  \
# 0   Laboratory of Immunopathogenesis and Bioinfor...  ...
#
#                                  category_list          keywords_list  \
# 0  Pathway, Standard ontology and nomenclature  functional annotation
#
#                           data_object_list               organism_list  \
# 0  Animal, Plant, Fungi, Bacteria, Archaea  Homo sapiens, Mus musculus
#
#   theme_list  zindex first_publication_year search_example  \
# 0             1847.8                   2007           None
#
#             cited_date  ess
# 0  2022-12-04 00:01:00    0
#
# [1 rows x 42 columns]

# %% [markdown]
# ### Save the Pages of Data Portals (`data-portal_pages.csv`)

# %%
"""
Create `data-portal_pages.csv` and add homepage urls.
"""
df_meta = pd.read_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'data-portal_metadata.csv'))

df_pages = df_meta[['id', 'url']].copy()

df_pages['page_type'] = 'home'
df_pages['page_id'] = df_pages['id']
df_pages['page_id'] = df_pages['page_id'].apply(lambda x: str(x) + '_' + 'home')

df_pages.to_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'data-portal_pages.csv'), index=False)

# %% [markdown]
# ## Journals

# %%
"""
Load the original data
"""
df = pd.read_csv(os.path.join('../input', EVALUATION_DATE_FOLDER, 'scimagojr 2022.csv'), sep=';')

# df = df.head(5) # for testing purposes

# %%
"""
Using `Sourceid` of SJR, get URLs of individual journal portals
TODO: Reuse the previously identified home pages
"""
def infer_homepage(Sourceid):
    info_url = f'https://www.scimagojr.com/journalsearch.php?q={Sourceid}&tip=sid&clean=0'
    html_text = requests.get(info_url).text
    soup = BeautifulSoup(html_text, 'html.parser')
    urls = soup.find_all('a', text=re.compile('Homepage'))
    if len(urls) > 0:
        return urls[0].get('href')
    else:
        print(f'No homepage found for {Sourceid}')
        return None

df['url'] = df['Sourceid'].apply(lambda x: infer_homepage(x))
# Out:
# /var/folders/rs/7nt0b63d5pn3m6rd7m8zt_6r0000gn/T/ipykernel_16924/1668964650.py:8: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   urls = soup.find_all('a', text=re.compile('Homepage'))
# No homepage found for 30611
# No homepage found for 110362
# No homepage found for 21100239245
# No homepage found for 19700175113
# No homepage found for 81474
# No homepage found for 5000158305
# No homepage found for 71628
# No homepage found for 25392
# No homepage found for 21100784787
# No homepage found for 21101070303
# No homepage found for 21101019253
# No homepage found for 21100983356
# No homepage found for 27392
# No homepage found for 21101047803
# No homepage found for 21100894516
# No homepage found for 19900191708
# No homepage found for 21100851290
# No homepage found for 21100223326
# No homepage found for 21100851285
# No homepage found for 18264
# No homepage found for 21100896491
# No homepage found for 21100239235
# No homepage found for 21100905330
# No homepage found for 14395
# No homepage found for 21100784717
# No homepage found for 22545
# No homepage found for 21100243806
# No homepage found for 83986
# No homepage found for 21101058912
# No homepage found for 21101081510
# No homepage found for 21100314711
# No homepage found for 21100313904
# No homepage found for 21100215706
# No homepage found for 21101041809
# No homepage found for 27974
# No homepage found for 21101042490
# No homepage found for 52142
# No homepage found for 21100784450
# No homepage found for 21100199856
# No homepage found for 21100201082
# No homepage found for 21101077109
# No homepage found for 4300151409
# No homepage found for 21101064915
# No homepage found for 17700156413
# No homepage found for 21100284963
# No homepage found for 21100894629
# No homepage found for 21100817408
# No homepage found for 21100784713
# No homepage found for 58655
# No homepage found for 21100784723
# No homepage found for 21100787658
# No homepage found for 26158
# No homepage found for 4400151708
# No homepage found for 21101017598
# No homepage found for 59863
# No homepage found for 24371
# No homepage found for 18039
# No homepage found for 19900193210
# No homepage found for 21101038513
# No homepage found for 21100244649
# No homepage found for 4500151502
# No homepage found for 12000154489
# No homepage found for 21100932526
# No homepage found for 26332
# No homepage found for 21100984844
# No homepage found for 21100255440
# No homepage found for 29654
# No homepage found for 19900192339
# No homepage found for 11700154733
# No homepage found for 31350
# No homepage found for 21100448516
# No homepage found for 26290
# No homepage found for 19700201511
# No homepage found for 21100198926
# No homepage found for 94730
# No homepage found for 21100901206
# No homepage found for 21100202940
# No homepage found for 21101052807
# No homepage found for 21100438059
# No homepage found for 21100314709
# No homepage found for 21101058282
# No homepage found for 21100891177
# No homepage found for 21100937445
# No homepage found for 27877
# No homepage found for 21101043236
# No homepage found for 18683
# No homepage found for 21100896681
# No homepage found for 21100408176
# No homepage found for 21100970247
# No homepage found for 21100255498
# No homepage found for 21101045325
# No homepage found for 21101017116
# No homepage found for 20544
# No homepage found for 29458
# No homepage found for 4300151406
# No homepage found for 21101061700
# No homepage found for 6100153022
# No homepage found for 21100806906
# No homepage found for 21100871775
# No homepage found for 19600162007
# No homepage found for 75113
# No homepage found for 21100932470
# No homepage found for 21100861792
# No homepage found for 144897
# No homepage found for 21100244868
# No homepage found for 21100239244
# No homepage found for 27930
# No homepage found for 21100239246
# No homepage found for 15900154752
# No homepage found for 97616
# No homepage found for 13027
# No homepage found for 21100898538
# No homepage found for 12889
# No homepage found for 21100854712
# No homepage found for 100147322
# No homepage found for 146161
# No homepage found for 21100906923
# No homepage found for 27048
# No homepage found for 15597
# No homepage found for 21100841738
# No homepage found for 20500195044
# No homepage found for 13901
# No homepage found for 22679
# No homepage found for 21100858674
# No homepage found for 21100992407
# No homepage found for 25682
# No homepage found for 21100370874
# No homepage found for 21101067744
# No homepage found for 21100893575
# No homepage found for 96562
# No homepage found for 21100897703
# No homepage found for 21100869886
# No homepage found for 21101022194
# No homepage found for 5000153602
# No homepage found for 93709
# No homepage found for 15664
# No homepage found for 61068
# No homepage found for 19500157034
# No homepage found for 21100218390
# No homepage found for 21101050920
# No homepage found for 5200153101
# No homepage found for 19700182301
# No homepage found for 21100450083
# No homepage found for 19712
# No homepage found for 21100853837
# No homepage found for 19700176038
# No homepage found for 26416
# No homepage found for 21100258747
# No homepage found for 57168
# No homepage found for 3300147401
# No homepage found for 54337
# No homepage found for 94558
# No homepage found for 21100906907
# No homepage found for 146159
# No homepage found for 21101049548
# No homepage found for 21100867241
# No homepage found for 13225
# No homepage found for 21100267917
# No homepage found for 19900195075
# No homepage found for 21100236605
# No homepage found for 79015
# No homepage found for 28985
# No homepage found for 37960
# No homepage found for 17800156701
# No homepage found for 21100922651
# No homepage found for 17155
# No homepage found for 12400154728
# No homepage found for 21100916528
# No homepage found for 21100898023
# No homepage found for 21100945724
# No homepage found for 21100455430
# No homepage found for 99670
# No homepage found for 6500153244
# No homepage found for 5100155027
# No homepage found for 4700152482
# No homepage found for 21100921050
# No homepage found for 23472
# No homepage found for 22386
# No homepage found for 5100154602
# No homepage found for 17093
# No homepage found for 87774
# No homepage found for 21100992514
# No homepage found for 21101056823
# No homepage found for 56053
# No homepage found for 15900154720
# No homepage found for 3900148614
# No homepage found for 11800154586
# No homepage found for 19300156808
# No homepage found for 21101054413
# No homepage found for 21100820608
# No homepage found for 21100920036
# No homepage found for 21100903414
# No homepage found for 16800154715
# No homepage found for 21101049095
# No homepage found for 21100197928
# No homepage found for 21100934922
# No homepage found for 12900154728
# No homepage found for 10300153374
# No homepage found for 145331
# No homepage found for 144884
# No homepage found for 27764
# No homepage found for 21100902612
# No homepage found for 21101064905
# No homepage found for 16682
# No homepage found for 10900153321
# No homepage found for 23348
# No homepage found for 19900193558
# No homepage found for 21100845829
# No homepage found for 19700175179
# No homepage found for 21100805730
# No homepage found for 19700182104
# No homepage found for 21101039864
# No homepage found for 21101032633
# No homepage found for 21101046187
# No homepage found for 21100905277
# No homepage found for 21100242263
# No homepage found for 21100201539
# No homepage found for 21100797723
# No homepage found for 26207
# No homepage found for 5600155441
# No homepage found for 21101039079
# No homepage found for 22178
# No homepage found for 21100466423
# No homepage found for 14451
# No homepage found for 19903
# No homepage found for 21100264366
# No homepage found for 20300195003
# No homepage found for 21100902603
# No homepage found for 21100818501
# No homepage found for 145258
# No homepage found for 19700188163
# No homepage found for 21101052702
# No homepage found for 29565
# No homepage found for 24508
# No homepage found for 21100901948
# No homepage found for 6000195382
# No homepage found for 25198
# No homepage found for 19700169104
# No homepage found for 20958
# No homepage found for 21100901155
# No homepage found for 21100219925
# No homepage found for 11700154615
# No homepage found for 21101072387
# No homepage found for 21100902625
# No homepage found for 6400153168
# No homepage found for 20703
# No homepage found for 4700152458
# No homepage found for 21101089994
# No homepage found for 19700174680
# No homepage found for 32882
# No homepage found for 21101038737
# No homepage found for 21100894743
# No homepage found for 21100325444
# No homepage found for 21100920640
# No homepage found for 21100223162
# No homepage found for 144725
# No homepage found for 3200147701
# No homepage found for 4000148022
# No homepage found for 19700174924
# No homepage found for 11700154336
# No homepage found for 21101047125
# No homepage found for 21100836264
# No homepage found for 21101059784
# No homepage found for 21100317750
# No homepage found for 145096
# No homepage found for 21101083977
# No homepage found for 21100942909
# No homepage found for 21100417267
# No homepage found for 21100258947
# No homepage found for 29797
# No homepage found for 145055
# No homepage found for 19900193275
# No homepage found for 17700156006
# No homepage found for 28079
# No homepage found for 27815
# No homepage found for 7200153124
# No homepage found for 21100857772
# No homepage found for 5800208171
# No homepage found for 21101034371
# No homepage found for 21692
# No homepage found for 144715
# No homepage found for 20759
# No homepage found for 21100934237
# No homepage found for 25605
# No homepage found for 21100898973
# No homepage found for 145261
# No homepage found for 21101058296
# No homepage found for 80911
# No homepage found for 19900192174
# No homepage found for 21100930958
# No homepage found for 4700152869
# No homepage found for 21100905326
# No homepage found for 19700175150
# No homepage found for 5700191202
# No homepage found for 27766
# No homepage found for 21100897507
# No homepage found for 19900192605
# No homepage found for 21100199816
# No homepage found for 17700156004
# No homepage found for 67906
# No homepage found for 12100154401
# No homepage found for 5700191221
# No homepage found for 11600154152
# No homepage found for 21100814501
# No homepage found for 21100889407
# No homepage found for 21101037318
# No homepage found for 21100896882
# No homepage found for 21100833806
# No homepage found for 21100218072
# No homepage found for 21101073717
# No homepage found for 21101070214
# No homepage found for 12306
# No homepage found for 100364
# No homepage found for 21100825365
# No homepage found for 14178
# No homepage found for 21100842862
# No homepage found for 19700186869
# No homepage found for 12513
# No homepage found for 21101070989
# No homepage found for 21100913137
# No homepage found for 21585
# No homepage found for 33328
# No homepage found for 19824
# No homepage found for 21100200825
# No homepage found for 21100211330
# No homepage found for 21100448010
# No homepage found for 17700155820
# No homepage found for 21100902659
# No homepage found for 21100904316
# No homepage found for 21100197512
# No homepage found for 21100788963
# No homepage found for 5700165171
# No homepage found for 21101039169
# No homepage found for 13000154716
# No homepage found for 32265
# No homepage found for 16084
# No homepage found for 19700182903
# No homepage found for 21101089491
# No homepage found for 5300152517
# No homepage found for 26681
# No homepage found for 21101045755
# No homepage found for 21100903186
# No homepage found for 19900191975
# No homepage found for 21100208082
# No homepage found for 19700190300
# No homepage found for 24566
# No homepage found for 21258
# No homepage found for 4000152133
# No homepage found for 21101023977
# No homepage found for 19320
# No homepage found for 145503
# No homepage found for 21100900149
# No homepage found for 21101079106
# No homepage found for 27928
# No homepage found for 21101007458
# No homepage found for 19700166604
# No homepage found for 69279
# No homepage found for 5400152618
# No homepage found for 11100153313
# No homepage found for 21101007457
# No homepage found for 19700175287
# No homepage found for 24110
# No homepage found for 19200157024
# No homepage found for 21840
# No homepage found for 21100888250
# No homepage found for 28136
# No homepage found for 21100781873
# No homepage found for 27231
# No homepage found for 17700155406
# No homepage found for 19400157005
# No homepage found for 19900192590
# No homepage found for 21100784273
# No homepage found for 21101021753
# No homepage found for 21100795043
# No homepage found for 51335
# No homepage found for 21100970234
# No homepage found for 25215
# No homepage found for 22703
# No homepage found for 21101042008
# No homepage found for 21101044919
# No homepage found for 21101064339
# No homepage found for 21000195014
# No homepage found for 18949
# No homepage found for 29685
# No homepage found for 21100239237
# No homepage found for 21101053110
# No homepage found for 130108
# No homepage found for 21101038744
# No homepage found for 21100920051
# No homepage found for 21072
# No homepage found for 21100915633
# No homepage found for 21979
# No homepage found for 22917
# No homepage found for 21101066399
# No homepage found for 21101062491
# No homepage found for 4900153503
# No homepage found for 21100983357
# No homepage found for 21101066734
# No homepage found for 21101050907
# No homepage found for 21101100274
# No homepage found for 25920
# No homepage found for 21101023717
# No homepage found for 40487
# No homepage found for 21101056817
# No homepage found for 21100204506
# No homepage found for 21100901776
# No homepage found for 26708
# No homepage found for 21101077284
# No homepage found for 12636
# No homepage found for 21101066988
# No homepage found for 19700166617
# No homepage found for 26993
# No homepage found for 20521
# No homepage found for 21100317746
# No homepage found for 21101042009
# No homepage found for 21101083190
# No homepage found for 11100153312
# No homepage found for 21827
# No homepage found for 21101056917
# No homepage found for 144788
# No homepage found for 21101039168
# No homepage found for 21100913891
# No homepage found for 21100825369
# No homepage found for 21100903780
# No homepage found for 60873
# No homepage found for 12114
# No homepage found for 21101039055
# No homepage found for 32655
# No homepage found for 13654
# No homepage found for 21100242828
# No homepage found for 99334
# No homepage found for 13218
# No homepage found for 18599
# No homepage found for 26090
# No homepage found for 21101053549
# No homepage found for 19900192126
# No homepage found for 27801
# No homepage found for 27112
# No homepage found for 21100926538
# No homepage found for 5700164553
# No homepage found for 24977
# No homepage found for 24068
# No homepage found for 21101017020
# No homepage found for 21101019266
# No homepage found for 94365
# No homepage found for 145354
# No homepage found for 19700188396
# No homepage found for 61342
# No homepage found for 21100324984
# No homepage found for 18404
# No homepage found for 19700171709
# No homepage found for 73326
# No homepage found for 21100775395
# No homepage found for 21100203945
# No homepage found for 96394
# No homepage found for 144806
# No homepage found for 19700200704
# No homepage found for 21101066747
# No homepage found for 21101041818
# No homepage found for 87387
# No homepage found for 78747
# No homepage found for 21101020096
# No homepage found for 21101098814
# No homepage found for 21100970227
# No homepage found for 10900153310
# No homepage found for 21101033833
# No homepage found for 12744
# No homepage found for 19700174946
# No homepage found for 21101063738
# No homepage found for 19900194914
# No homepage found for 14421
# No homepage found for 19381
# No homepage found for 18038
# No homepage found for 21101048275
# No homepage found for 21101075017
# No homepage found for 12100154831
# No homepage found for 21101041557
# No homepage found for 18332
# No homepage found for 13804
# No homepage found for 19700174803
# No homepage found for 21100893337
# No homepage found for 144813
# No homepage found for 19900193610
# No homepage found for 21101039893
# No homepage found for 13000154717
# No homepage found for 15861
# No homepage found for 21100274701
# No homepage found for 21101061921
# No homepage found for 5300152224
# No homepage found for 19200156926
# No homepage found for 21100923447
# No homepage found for 13592
# No homepage found for 21101050038
# No homepage found for 21101056822
# No homepage found for 21100255701
# No homepage found for 28481
# No homepage found for 7200153193
# No homepage found for 21100207641
# No homepage found for 21101067738
# No homepage found for 21101089399
# No homepage found for 21101062494
# No homepage found for 21101046253
# No homepage found for 21100890298
# No homepage found for 18800156701
# No homepage found for 21101060129
# No homepage found for 21456
# No homepage found for 145378
# No homepage found for 21101037322
# No homepage found for 11700154379
# No homepage found for 21101081517
# No homepage found for 21101054226
# No homepage found for 21101064227
# No homepage found for 21101020034
# No homepage found for 24457
# No homepage found for 21820
# No homepage found for 21101055893
# No homepage found for 21100207012
# No homepage found for 21101048279
# No homepage found for 21101055931
# No homepage found for 21100328250
# No homepage found for 21101074754
# No homepage found for 21101067520
# No homepage found for 29789
# No homepage found for 21101068033
# No homepage found for 21100286805
# No homepage found for 14052
# No homepage found for 17170
# No homepage found for 21000195015
# No homepage found for 28942
# No homepage found for 94708
# No homepage found for 21100881509
# No homepage found for 29590
# No homepage found for 21100201531
# No homepage found for 21100983354
# No homepage found for 21101092871
# No homepage found for 21857
# No homepage found for 21100905904
# No homepage found for 18755
# No homepage found for 21100202513
# No homepage found for 28615
# No homepage found for 4000151706
# No homepage found for 14425
# No homepage found for 21100445641
# No homepage found for 19400157214
# No homepage found for 29505
# No homepage found for 21100983352
# No homepage found for 13000154722
# No homepage found for 21100860142
# No homepage found for 21101089568
# No homepage found for 21101051212
# No homepage found for 22179
# No homepage found for 21495
# No homepage found for 20600195060
# No homepage found for 21101020033
# No homepage found for 20008
# No homepage found for 4000151811
# No homepage found for 21100258631
# No homepage found for 19700188346
# No homepage found for 11700154352
# No homepage found for 21101105025
# No homepage found for 21100310015
# No homepage found for 21101058177
# No homepage found for 25187
# No homepage found for 9100153105
# No homepage found for 33335
# No homepage found for 21101053100
# No homepage found for 16698
# No homepage found for 17850
# No homepage found for 12541
# No homepage found for 28693
# No homepage found for 21101089961
# No homepage found for 4700152446
# No homepage found for 5000155404
# No homepage found for 144807
# No homepage found for 27931
# No homepage found for 71152
# No homepage found for 13536
# No homepage found for 13462
# No homepage found for 144648
# No homepage found for 21100980645
# No homepage found for 21101044977
# No homepage found for 21974
# No homepage found for 21101072518
# No homepage found for 87636
# No homepage found for 19600157363
# No homepage found for 19700166523
# No homepage found for 19657
# No homepage found for 93609
# No homepage found for 21101059300
# No homepage found for 21100236827
# No homepage found for 12934
# No homepage found for 21100932463
# No homepage found for 16200154757
# No homepage found for 17115
# No homepage found for 18737
# No homepage found for 5000153109
# No homepage found for 21100227422
# No homepage found for 26726
# No homepage found for 50142
# No homepage found for 12019
# No homepage found for 14854
# No homepage found for 21101062031
# No homepage found for 21101061446
# No homepage found for 26154
# No homepage found for 4100151704
# No homepage found for 21000195013
# No homepage found for 5800208631
# No homepage found for 144719
# No homepage found for 5000159102
# No homepage found for 17700156003
# No homepage found for 18290
# No homepage found for 24854
# No homepage found for 30856
# No homepage found for 18400156709
# No homepage found for 21101068032
# No homepage found for 19700201343
# No homepage found for 21101089621
# No homepage found for 58808
# No homepage found for 27918
# No homepage found for 19700174884
# No homepage found for 13373
# No homepage found for 144808
# No homepage found for 3800148001
# No homepage found for 15800
# No homepage found for 64675
# No homepage found for 25512
# No homepage found for 19700200818
# No homepage found for 19700201134
# No homepage found for 32829
# No homepage found for 24755
# No homepage found for 24896
# No homepage found for 21100877310
# No homepage found for 14342
# No homepage found for 21101089092
# No homepage found for 88686
# No homepage found for 21100332198
# No homepage found for 5800152987
# No homepage found for 29860
# No homepage found for 5700182228
# No homepage found for 4700152456
# No homepage found for 21100275406
# No homepage found for 22323
# No homepage found for 21100264811
# No homepage found for 21100967248
# No homepage found for 13946
# No homepage found for 19909
# No homepage found for 27270
# No homepage found for 21100267937
# No homepage found for 8400155881
# No homepage found for 16300154750
# No homepage found for 21101058309
# No homepage found for 21100837393
# No homepage found for 28687
# No homepage found for 21100236219
# No homepage found for 17930
# No homepage found for 16100154776
# No homepage found for 28340
# No homepage found for 29790
# No homepage found for 65544
# No homepage found for 21101067705
# No homepage found for 12751
# No homepage found for 15985
# No homepage found for 16540
# No homepage found for 20165
# No homepage found for 15180
# No homepage found for 19400157323
# No homepage found for 50178
# No homepage found for 19700168708
# No homepage found for 21100253111
# No homepage found for 21101095134
# No homepage found for 12100155426
# No homepage found for 53718
# No homepage found for 11600153637
# No homepage found for 24954
# No homepage found for 17386
# No homepage found for 5800208059
# No homepage found for 16400154724
# No homepage found for 21100880190
# No homepage found for 300147007
# No homepage found for 18910
# No homepage found for 66748
# No homepage found for 5800158153
# No homepage found for 21101063735
# No homepage found for 19379
# No homepage found for 21000195316
# No homepage found for 21438
# No homepage found for 15007
# No homepage found for 28365
# No homepage found for 16200154732
# No homepage found for 100069
# No homepage found for 15996
# No homepage found for 20496
# No homepage found for 19900193939
# No homepage found for 21100243005
# No homepage found for 20469
# No homepage found for 13767
# No homepage found for 15661
# No homepage found for 15678
# No homepage found for 21100451643
# No homepage found for 21101063723
# No homepage found for 16100154797
# No homepage found for 19630
# No homepage found for 84226
# No homepage found for 21100877171
# No homepage found for 17700154927
# No homepage found for 21101092539
# No homepage found for 15294
# No homepage found for 21101089569
# No homepage found for 21101044895
# No homepage found for 21101079250
# No homepage found for 26231
# No homepage found for 21101089401
# No homepage found for 21101101213
# No homepage found for 21101091129
# No homepage found for 21101104290
# No homepage found for 21101097260
# No homepage found for 19600156826
# No homepage found for 21101101867
# No homepage found for 21100896881
# No homepage found for 21101089140
# No homepage found for 21101089397
# No homepage found for 21101091646
# No homepage found for 21101098811
# No homepage found for 21101091648
# No homepage found for 21841
# No homepage found for 21101053535
# No homepage found for 73931
# No homepage found for 21101089392
# No homepage found for 21100381259
# No homepage found for 20000195053
# No homepage found for 21100201518
# No homepage found for 21101077474
# No homepage found for 21101016918
# No homepage found for 21101091649
# No homepage found for 21101090148
# No homepage found for 5300152608
# No homepage found for 21101093540
# No homepage found for 21101090013
# No homepage found for 21101101245
# No homepage found for 21101093006
# No homepage found for 11600154151
# No homepage found for 21101093583
# No homepage found for 21101094914
# No homepage found for 21100824403
# No homepage found for 21101104815
# No homepage found for 21101089141
# No homepage found for 21101092814
# No homepage found for 21101100204
# No homepage found for 21101104871
# No homepage found for 21100908447
# No homepage found for 21101100276
# No homepage found for 21101084975
# No homepage found for 21101098863
# No homepage found for 21101085528
# No homepage found for 21101089370
# No homepage found for 21101023074
# No homepage found for 5700167234
# No homepage found for 21100874917
# No homepage found for 21101091736
# No homepage found for 17700156005
# No homepage found for 19856

# %%
"""
We use underscore lowercase column names
"""
df.columns = (df.columns.str.replace('(?<=[a-z])(?=[A-Z])', '_', regex=True).str.lower())
df.columns = (df.columns.str.replace('.', '')) # remove dots
df.columns = (df.columns.str.replace('(', '')) # remove parentheses
df.columns = (df.columns.str.replace(')', ''))
df.columns = (df.columns.str.replace('/', 'per')) # replace slash with "per"
df.columns = (df.columns.str.replace(' ', '_')) # replace space with underscore

# %%
"""
The id from the sources are consistently "source_id"
The values should be a string type, and it has the prefix that represents the source (e.g. dc_ for Database Commons)
"""
df.rename(columns={ "sourceid": "source_id" }, inplace=True)
df.source_id = df.source_id.apply(lambda x: 'sjr_' + str(x))

# %% [markdown]
# ### Update the ID Mapping Table (`journal-portal_id_map.csv`)

# %%
"""
create or update a mapping table (i.e., `data-portal_id_map.csv`)
"""
# Load the data first
file = Path(os.path.join('../output', 'journal-portal_id_map.csv'))
if file.exists():
    df_map = pd.read_csv(file)
else:
    df_map = pd.DataFrame(columns=['id', 'source_id', 'date_added'])

# Find rows that does not already exist in the table
df_temp = df_map.merge(df, how='outer', on='source_id', indicator=True)
df_new_resources = df_temp[df_temp['_merge'] == 'right_only'][['source_id']]

# Ensure to assign new `id`s, i.e., New `id` == max id + 1
max_id = df_map.id.max()
max_id = 0 if max_id is np.nan else max_id
new_id = max_id + 1

df_new_resources.insert(0, 'id', range(new_id, new_id + len(df_new_resources)))
df_new_resources['date_added'] = pd.to_datetime('today').strftime('%m-%d-%Y')

pd.concat([df_map, df_new_resources], axis=0).to_csv(file, index=False)

# %% [markdown]
# ### Save the Metadata of Journal Portals (`journal-portal_metadata.csv`)

# %%
"""
Add the `id` column to the original metadata
"""
df_map = pd.read_csv(file)
df_meta = df_map[['id', 'source_id']].merge(df, how='right', on='source_id')
df_meta.to_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'journal-portal_metadata.csv'), index=False)
df_meta.head(10)
# Out:
#       id            source_id  rank                                  title  \
# 0  27956        sjr_sjr_28773     1     Ca-A Cancer Journal for Clinicians
# 1  27957        sjr_sjr_29431     2         Quarterly Journal of Economics
# 2  27958        sjr_sjr_20315     3  Nature Reviews Molecular Cell Biology
# 3  27959        sjr_sjr_18434     4                                   Cell
# 4  27960        sjr_sjr_15847     5        New England Journal of Medicine
# 5  27961        sjr_sjr_15819     6                        Nature Medicine
# 6  27962        sjr_sjr_19434     7       MMWR Recommendations and Reports
# 7  27963        sjr_sjr_16115     8                   Nature Biotechnology
# 8  27964  sjr_sjr_21100812243     9               Nature Reviews Materials
# 9  27965        sjr_sjr_22697    10               American Economic Review
#
#       type                issn     sjr sjr_best_quartile  h_index  \
# 0  journal  15424863, 00079235  86,091                Q1      198
# 1  journal  00335533, 15314650  36,730                Q1      292
# 2  journal  14710072, 14710080  34,201                Q1      485
# 3  journal  00928674, 10974172  26,494                Q1      856
# 4  journal  00284793, 15334406  26,015                Q1     1130
# 5  journal  1546170X, 10788956  24,687                Q1      605
# 6  journal  10575987, 15458601  23,962                Q1      151
# 7  journal  15461696, 10870156  22,781                Q1      491
# 8  journal            20588437  21,927                Q1      156
# 9  journal            00028282  21,833                Q1      337
#
#    total_docs_2022  ...  citable_docs_3years  cites_per_doc_2years  \
# 0               44  ...                   85                299,99
# 1               36  ...                  122                 14,83
# 2              121  ...                  156                 35,47
# 3              420  ...                 1440                 43,80
# 4             1410  ...                 1854                 33,93
# 5              522  ...                  664                 34,67
# 6              103  ...                  133                 25,28
# 7              423  ...                  426                 16,35
# 8              122  ...                  168                 40,82
# 9               71  ...                  354                  9,78
#
#    ref_per_doc         country            region  \
# 0        97,00   United States  Northern America
# 1        66,61  United Kingdom    Western Europe
# 2        89,29  United Kingdom    Western Europe
# 3        65,74   United States  Northern America
# 4        10,21   United States  Northern America
# 5        29,23  United Kingdom    Western Europe
# 6         9,13   United States  Northern America
# 7        25,65  United Kingdom    Western Europe
# 8        90,43  United Kingdom    Western Europe
# 9        59,68   United States  Northern America
#
#                                           publisher              coverage  \
# 0                                   Wiley-Blackwell             1950-2022
# 1                           Oxford University Press             1886-2022
# 2                           Nature Publishing Group             2000-2022
# 3                                        Cell Press             1974-2022
# 4                    Massachussetts Medical Society             1945-2022
# 5                           Nature Publishing Group             1995-2022
# 6  Centers for Disease Control and Prevention (CDC)             1990-2022
# 7                           Nature Publishing Group             1989-2022
# 8                           Nature Publishing Group             2016-2022
# 9                     American Economic Association  1973-1975, 1978-2022
#
#                                           categories  \
# 0                     Hematology (Q1); Oncology (Q1)
# 1                    Economics and Econometrics (Q1)
# 2          Cell Biology (Q1); Molecular Biology (Q1)
# 3  Biochemistry, Genetics and Molecular Biology (...
# 4                      Medicine (miscellaneous) (Q1)
# 5  Biochemistry, Genetics and Molecular Biology (...
# 6  Epidemiology (Q1); Health Information Manageme...
# 7  Applied Microbiology and Biotechnology (Q1); B...
# 8  Biomaterials (Q1); Electronic, Optical and Mag...
# 9                    Economics and Econometrics (Q1)
#
#                                                areas  \
# 0                                           Medicine
# 1                Economics, Econometrics and Finance
# 2       Biochemistry, Genetics and Molecular Biology
# 3       Biochemistry, Genetics and Molecular Biology
# 4                                           Medicine
# 5  Biochemistry, Genetics and Molecular Biology; ...
# 6  Environmental Science; Health Professions; Med...
# 7  Biochemistry, Genetics and Molecular Biology; ...
# 8                          Energy; Materials Science
# 9                Economics, Econometrics and Finance
#
#                                                 url
# 0  https://onlinelibrary.wiley.com/journal/15424863
# 1                      https://academic.oup.com/qje
# 2                       https://www.nature.com/nrm/
# 3                    https://www.cell.com/cell/home
# 4                             https://www.nejm.org/
# 5                        https://www.nature.com/nm/
# 6          https://www.cdc.gov/mmwr/indrr_2020.html
# 7                       https://www.nature.com/nbt/
# 8                https://www.nature.com/natrevmats/
# 9               https://www.aeaweb.org/journals/aer
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Save the Pages of Journal Portals (`journal-portal_pages.csv`)

# %%
"""
Create `*_pages.csv` and add homepage urls.
"""
df_meta = pd.read_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'journal-portal_metadata.csv'))

df_pages = df_meta[['id', 'url']].copy()

df_pages['page_type'] = 'home'
df_pages['page_id'] = df_pages['id']
df_pages['page_id'] = df_pages['page_id'].apply(lambda x: str(x) + '_' + 'home')

df_pages.to_csv(os.path.join('../output', EVALUATION_DATE_FOLDER, 'journal-portal_pages.csv'), index=False)

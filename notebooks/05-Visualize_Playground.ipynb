# %%
import pandas as pd
import altair as alt
import os
alt.data_transformers.disable_max_rows(); # Allow using rows more than 5000

# %% [markdown]
# # Visualize
# For previous code, refer to `./deprecated/04-Visualize.ipynb`.

# %%
# The folder that contains the metadata and evlauation results
EVALUATION_DATE_FOLDER = 'Nov-21-2023'

# %% [markdown]
# ## Journal Portals
# ### Basic data warngling

# %%
"""
Merge data for visualization
"""
df = pd.read_csv(os.path.join('..', 'output', EVALUATION_DATE_FOLDER, 'journal-portal_evaluation.csv'))

# Can be useful for visualization
ERROR_TYPES = df.columns.tolist()
ERROR_TYPES.remove('page_id')
ERROR_TYPES.remove('is_success')
ERROR_TYPES.remove('error_count')

# Add `id` of resources and `page_type` of pages
df_pages = pd.read_csv(os.path.join('..', 'output', EVALUATION_DATE_FOLDER, 'journal-portal_pages.csv'))
df = df.merge(df_pages[['id', 'page_id', 'page_type']], left_on='page_id', right_on='page_id', how='left')

# Add metadata of resources
df_meta = pd.read_csv(os.path.join('..', 'output', EVALUATION_DATE_FOLDER, 'journal-portal_metadata.csv'))
df_meta.drop(columns=['url'], inplace=True)
df = df.merge(df_meta, left_on='id', right_on='id', how='left')

df.head(3)
# df.title
df
# Out:
#                       page_id  is_success  error_count  aria_reference_broken  \
# 0                     12_home        True          0.0                    NaN
# 1         12_research_article        True          1.0                    1.0
# 2    12_none_research_article        True          2.0                    NaN
# 3    12_article_search_result        True          0.0                    NaN
# 4             12_latest_issue        True          0.0                    NaN
# ..                        ...         ...          ...                    ...
# 95                   179_home        True          3.0                    NaN
# 96       179_research_article       False          NaN                    NaN
# 97  179_none_research_article        True          0.0                    NaN
# 98  179_article_search_result        True         54.0                    NaN
# 99           179_latest_issue       False          NaN                    NaN
#
#     label_multiple  alt_missing  alt_link_missing  label_empty  button_empty  \
# 0              NaN          NaN               NaN          NaN           NaN
# 1              NaN          NaN               NaN          NaN           NaN
# 2              2.0          NaN               NaN          NaN           NaN
# 3              NaN          NaN               NaN          NaN           NaN
# 4              NaN          NaN               NaN          NaN           NaN
# ..             ...          ...               ...          ...           ...
# 95             NaN          NaN               NaN          NaN           3.0
# 96             NaN          NaN               NaN          NaN           3.0
# 97             NaN          NaN               NaN          NaN           NaN
# 98             NaN          NaN               5.0          NaN           NaN
# 99             NaN          NaN               5.0          NaN           NaN
#
#     link_empty  ...  total_cites_3years  citable_docs_3years  \
# 0          NaN  ...              168543                 3565
# 1          NaN  ...              168543                 3565
# 2          NaN  ...              168543                 3565
# 3          NaN  ...              168543                 3565
# 4          NaN  ...              168543                 3565
# ..         ...  ...                 ...                  ...
# 95         NaN  ...               10764                  828
# 96         NaN  ...               10764                  828
# 97         NaN  ...               10764                  828
# 98         5.0  ...               10764                  828
# 99         5.0  ...               10764                  828
#
#     cites_per_doc_2years  ref_per_doc         country            region  \
# 0                  23,95        21,59  United Kingdom    Western Europe
# 1                  23,95        21,59  United Kingdom    Western Europe
# 2                  23,95        21,59  United Kingdom    Western Europe
# 3                  23,95        21,59  United Kingdom    Western Europe
# 4                  23,95        21,59  United Kingdom    Western Europe
# ..                   ...          ...             ...               ...
# 95                 12,31        66,08   United States  Northern America
# 96                 12,31        66,08   United States  Northern America
# 97                 12,31        66,08   United States  Northern America
# 98                 12,31        66,08   United States  Northern America
# 99                 12,31        66,08   United States  Northern America
#
#                        publisher                          coverage  \
# 0        Nature Publishing Group                         1869-2022
# 1        Nature Publishing Group                         1869-2022
# 2        Nature Publishing Group                         1869-2022
# 3        Nature Publishing Group                         1869-2022
# 4        Nature Publishing Group                         1869-2022
# ..                           ...                               ...
# 95  Rockefeller University Press  1909-1910, 1929, 1938, 1945-2022
# 96  Rockefeller University Press  1909-1910, 1929, 1938, 1945-2022
# 97  Rockefeller University Press  1909-1910, 1929, 1938, 1945-2022
# 98  Rockefeller University Press  1909-1910, 1929, 1938, 1945-2022
# 99  Rockefeller University Press  1909-1910, 1929, 1938, 1945-2022
#
#                                            categories  \
# 0                              Multidisciplinary (Q1)
# 1                              Multidisciplinary (Q1)
# 2                              Multidisciplinary (Q1)
# 3                              Multidisciplinary (Q1)
# 4                              Multidisciplinary (Q1)
# ..                                                ...
# 95  Immunology (Q1); Immunology and Allergy (Q1); ...
# 96  Immunology (Q1); Immunology and Allergy (Q1); ...
# 97  Immunology (Q1); Immunology and Allergy (Q1); ...
# 98  Immunology (Q1); Immunology and Allergy (Q1); ...
# 99  Immunology (Q1); Immunology and Allergy (Q1); ...
#
#                                     areas
# 0                       Multidisciplinary
# 1                       Multidisciplinary
# 2                       Multidisciplinary
# 3                       Multidisciplinary
# 4                       Multidisciplinary
# ..                                    ...
# 95  Immunology and Microbiology; Medicine
# 96  Immunology and Microbiology; Medicine
# 97  Immunology and Microbiology; Medicine
# 98  Immunology and Microbiology; Medicine
# 99  Immunology and Microbiology; Medicine
#
# [100 rows x 41 columns]

# %%
# Let's add some useful columns for visualization
df['has_error'] = df.error_count.apply(lambda x: x > 0)

# %% [markdown]
# ### Create Altair Plots!

# %%
THEME_COLOR = '#CC7DAA'

# %%
alt.Chart(df).mark_point(filled=True, color=THEME_COLOR, size=100).encode(
    alt.X('mean(error_count):Q', title='Mean of Error Count'),
    alt.Y('page_type:N', title='Page Type'),
)
# Out:
# alt.Chart(...)
